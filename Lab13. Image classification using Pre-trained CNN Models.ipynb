# %% [markdown]
# ## Part - I

# %% [markdown]
# ### 1. Import and create

# %%
import tensorflow as tf
import keras

# %%
model = keras.applications.vgg16.VGG16(weights="imagenet")
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_4 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
# ...

# %% [markdown]
# ### 2. Use methods

# %%
img = tf.keras.preprocessing.image.load_img('download.jpg', target_size=(224, 224))
img = tf.keras.preprocessing.image.img_to_array(img)
img = np.expand_dims(img, axis=0)
img = tf.keras.applications.vgg16.preprocess_input(img)
pred = tf.keras.applications.vgg16.decode_predictions(model.predict(img), top=10)
# Out:
# 1/1 [==============================] - 0s 215ms/step

# %% [markdown]
# ### 3. Print predictions

# %%
pred
# Out:
# [[('n02129165', 'lion', 0.99992406),
#   ('n02112137', 'chow', 3.3603606e-05),
#   ('n02361337', 'marmot', 1.1540174e-05),
#   ('n02130308', 'cheetah', 4.993663e-06),
#   ('n02125311', 'cougar', 4.1775975e-06),
#   ('n02487347', 'macaque', 3.768886e-06),
#   ('n02363005', 'beaver', 2.9844784e-06),
#   ('n02132136', 'brown_bear', 2.394364e-06),
#   ('n02115913', 'dhole', 2.3703062e-06),
#   ('n02128925', 'jaguar', 2.1610265e-06)]]

# %% [markdown]
# ## Part - II

# %%
model1 = tf.keras.applications.resnet50.ResNet50(weights='imagenet')
model1.summary()
# Out:
# ...
# 102967424/102967424 [==============================] - 16s 0us/step
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_5 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_5[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 112, 112, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_relu[0][0]']
#                                 )
#
# ...

# %%
img = tf.keras.preprocessing.image.load_img('download.jpg', target_size=(224, 224))
img = tf.keras.preprocessing.image.img_to_array(img)
img = np.expand_dims(img, axis=0)
img = tf.keras.applications.resnet50.preprocess_input(img, data_format=None)
pred2 = tf.keras.applications.resnet50.decode_predictions(model1.predict(img) , top=10)
# Out:
# 1/1 [==============================] - 0s 128ms/step

# %%
pred2
# Out:
# [[('n02129165', 'lion', 0.9927457),
#   ('n02130308', 'cheetah', 0.0016311504),
#   ('n02437312', 'Arabian_camel', 0.0014663066),
#   ('n02125311', 'cougar', 0.0013369233),
#   ('n02486410', 'baboon', 0.00031903206),
#   ('n02410509', 'bison', 0.00021254123),
#   ('n02128925', 'jaguar', 0.00012928841),
#   ('n02363005', 'beaver', 0.00012822969),
#   ('n02437616', 'llama', 0.00012589697),
#   ('n02412080', 'ram', 0.00011720773)]]

# %% [markdown]
# ## Part - III

# %%
img = tf.keras.preprocessing.image.load_img('download.jpg', target_size=(224, 224))
img = tf.keras.preprocessing.image.img_to_array(img)
img = np.expand_dims(img, axis=0)
img = tf.keras.applications.vgg16.preprocess_input(img)
pred = tf.keras.applications.vgg16.decode_predictions(model.predict(img), top=10)

# %%
img = tf.keras.preprocessing.image.load_img('download.jpg', target_size=(224, 224))
img = tf.keras.preprocessing.image.img_to_array(img)
img = np.expand_dims(img, axis=0)
img = tf.keras.applications.resnet50.preprocess_input(img, data_format=None)
pred2 = tf.keras.applications.resnet50.decode_predictions(model1.predict(img) , top=10)

# %% [markdown]
# ## Part - IV

# %%
train = tf.keras.preprocessing.image.ImageDataGenerator(rotation_range=90, 
                                     brightness_range=[0.1, 0.7],
                                     width_shift_range=0.5, 
                                     height_shift_range=0.5,
                                     horizontal_flip=True, 
                                     vertical_flip=True,
                                     validation_split=0.15,
                                     preprocessing_function=preprocess_input)
train = train.flow_from_directory(directory="image.zip",target_size=(224,224))

# %%
test = tf.keras.preprocessing.image.ImageDataGenerator(rotation_range=90, 
                                     brightness_range=[0.1, 0.7],
                                     width_shift_range=0.5, 
                                     height_shift_range=0.5,
                                     horizontal_flip=True, 
                                     vertical_flip=True,
                                     validation_split=0.15,
                                     preprocessing_function=preprocess_input)
test = test.flow_from_directory(directory="image.zip", target_size=(224,224))
